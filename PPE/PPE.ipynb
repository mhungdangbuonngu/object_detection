# %%
from ultralytics import YOLO
import cv2
import cvzone
import time

# %% [markdown]
# ## PPE dataset

# %%
# !yolo task=detect mode=train model=yolov8n.pt data='/home/mhung/Documents/python/object_detection/PPE/data/data.yaml' epochs=50 imgsz=640 conf=0.25
# Out:
# Ultralytics 8.3.9 🚀 Python-3.9.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3895MiB)
# ...
